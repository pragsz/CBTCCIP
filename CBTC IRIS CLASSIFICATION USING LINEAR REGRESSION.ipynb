# %% [markdown]
# # IMPORTING THE LIBRARIES

# %%
import pandas as pd
import numpy as np

# %%
columns=['sepal_length','sepal_width','petal_length','petal_width','class']

# %% [markdown]
# # READING THE DATA

# %%
df=pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# # DATA PREPROCESSING

# %%
X=df.iloc[:,:4]
Y=df.iloc[:,4]

# %%
X
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0      1            5.1           3.5            1.4
# 1      2            4.9           3.0            1.4
# 2      3            4.7           3.2            1.3
# 3      4            4.6           3.1            1.5
# 4      5            5.0           3.6            1.4
# ..   ...            ...           ...            ...
# 145  146            6.7           3.0            5.2
# 146  147            6.3           2.5            5.0
# 147  148            6.5           3.0            5.2
# 148  149            6.2           3.4            5.4
# 149  150            5.9           3.0            5.1
#
# [150 rows x 4 columns]

# %%
Y
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: PetalWidthCm, Length: 150, dtype: float64

# %% [markdown]
# # PERFORMING TRAIN TEST SPLIT

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y ,test_size=0.3,random_state=4)

# %%
X_train
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 13    14            4.3           3.0            1.1
# 15    16            5.7           4.4            1.5
# 61    62            5.9           3.0            4.2
# 91    92            6.1           3.0            4.6
# 116  117            6.5           3.0            5.5
# ..   ...            ...           ...            ...
# 50    51            7.0           3.2            4.7
# 87    88            6.3           2.3            4.4
# 104  105            6.5           3.0            5.8
# 129  130            7.2           3.0            5.8
# 122  123            7.7           2.8            6.7
#
# [105 rows x 4 columns]

# %%
X_test
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 128  129            6.4           2.8            5.6
# 18    19            5.7           3.8            1.7
# 130  131            7.4           2.8            6.1
# 105  106            7.6           3.0            6.6
# 107  108            7.3           2.9            6.3
# 78    79            6.0           2.9            4.5
# 83    84            6.0           2.7            5.1
# 14    15            5.8           4.0            1.2
# 5      6            5.4           3.9            1.7
# 133  134            6.3           2.8            5.1
# 25    26            5.0           3.0            1.6
# 11    12            4.8           3.4            1.6
# 12    13            4.8           3.0            1.4
# 63    64            6.1           2.9            4.7
# 113  114            5.7           2.5            5.0
# 34    35            4.9           3.1            1.5
# 60    61            5.0           2.0            3.5
# 2      3            4.7           3.2            1.3
# 24    25            4.8           3.4            1.9
# 123  124            6.3           2.7            4.9
# 35    36            5.0           3.2            1.2
# 124  125            6.7           3.3            5.7
# 68    69            6.2           2.2            4.5
# 26    27            5.0           3.4            1.6
# 29    30            4.7           3.2            1.6
# 19    20            5.1           3.8            1.5
# 41    42            4.5           2.3            1.3
# 16    17            5.4           3.9            1.3
# 20    21            5.4           3.4            1.7
# 101  102            5.8           2.7            5.1
# 84    85            5.4           3.0            4.5
# 47    48            4.6           3.2            1.4
# 108  109            6.7           2.5            5.8
# 1      2            4.9           3.0            1.4
# 93    94            5.0           2.3            3.3
# 144  145            6.7           3.3            5.7
# 125  126            7.2           3.2            6.0
# 92    93            5.8           2.6            4.0
# 86    87            6.7           3.1            4.7
# 46    47            5.1           3.8            1.6
# 135  136            7.7           3.0            6.1
# 7      8            5.0           3.4            1.5
# 65    66            6.7           3.1            4.4
# 10    11            5.4           3.7            1.5
# 132  133            6.4           2.8            5.6

# %%
Y_train
# Out:
# 13     0.1
# 15     0.4
# 61     1.5
# 91     1.4
# 116    1.8
#       ...
# 50     1.4
# 87     1.3
# 104    2.2
# 129    1.6
# 122    2.0
# Name: PetalWidthCm, Length: 105, dtype: float64

# %%
Y_test
# Out:
# 128    2.1
# 18     0.3
# 130    1.9
# 105    2.1
# 107    1.8
# 78     1.5
# 83     1.6
# 14     0.2
# 5      0.4
# 133    1.5
# 25     0.2
# 11     0.2
# 12     0.1
# 63     1.4
# 113    2.0
# 34     0.1
# 60     1.0
# 2      0.2
# 24     0.2
# 123    1.8
# 35     0.2
# 124    2.1
# 68     1.5
# 26     0.4
# 29     0.2
# 19     0.3
# 41     0.3
# 16     0.4
# 20     0.2
# 101    1.9
# 84     1.5
# 47     0.2
# 108    1.8
# 1      0.2
# 93     1.0
# 144    2.5
# 125    1.8
# 92     1.2
# 86     1.5
# 46     0.2
# 135    2.3
# 7      0.2
# 65     1.4
# 10     0.2
# 132    2.2
# Name: PetalWidthCm, dtype: float64

# %% [markdown]
# # LABELLING THE DATA

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_Y = LabelEncoder()
Y = labelencoder_Y.fit_transform(Y)

# %%
Y
# Out:
# array([ 1,  1,  1,  1,  1,  3,  2,  1,  1,  0,  1,  1,  0,  0,  1,  3,  3,
#         2,  2,  2,  1,  3,  1,  4,  1,  1,  3,  1,  1,  1,  1,  3,  0,  1,
#         0,  1,  1,  0,  1,  1,  2,  2,  1,  5,  3,  2,  1,  1,  1,  1, 10,
#        11, 11,  9, 11,  9, 12,  6,  9, 10,  6, 11,  6, 10,  9, 10, 11,  6,
#        11,  7, 14,  9, 11,  8,  9, 10, 10, 13, 11,  6,  7,  6,  8, 12, 11,
#        12, 11,  9,  9,  9,  8, 10,  8,  6,  9,  8,  9,  9,  7,  9, 21, 15,
#        17, 14, 18, 17, 13, 14, 14, 21, 16, 15, 17, 16, 20, 19, 14, 18, 19,
#        11, 19, 16, 16, 14, 17, 14, 14, 14, 17, 12, 15, 16, 18, 11, 10, 19,
#        20, 14, 14, 17, 20, 19, 15, 19, 21, 19, 15, 16, 19, 14],
#       dtype=int64)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=reg.predict(X_test)

# %%
Y_pred
# Out:
# array([2.03897295, 0.30782393, 2.09210481, 2.24718642, 2.14841738,
#        1.48024026, 1.71547353, 0.10281856, 0.34278151, 1.8498315 ,
#        0.21452345, 0.30170817, 0.11822523, 1.50294972, 1.77279439,
#        0.24125691, 0.93249795, 0.10742639, 0.47791537, 1.70363815,
#        0.11739819, 2.13950257, 1.24172187, 0.31529122, 0.32925121,
#        0.32772929, 0.05040098, 0.20015997, 0.26977084, 1.80941775,
#        1.63004695, 0.31631695, 1.9369654 , 0.06473632, 1.02392525,
#        2.20467061, 2.16399915, 1.26493888, 1.5207687 , 0.46032213,
#        2.10421203, 0.20876559, 1.31849429, 0.22108686, 2.05200656])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df['SepalLengthCm'].plot.hist()
df['SepalWidthCm'].plot.hist()
df['PetalLengthCm'].plot.hist()
df['PetalWidthCm'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
plt.scatter(Y_test,Y_pred)
plt.xlabel("Actual Data")
plt.ylabel("Predicted Data")
# Out:
# Text(0, 0.5, 'Predicted Data')
